# %% [markdown]
# # Récréation : prévoir le résultat des instructions suivantes

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
False - True
# Out:
# -1

# %%
(5 / 2 - 5 // 2) / ( (5 <= 2) and (2 < 5) )
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 (5 / 2 - 5 // 2) / ( (5 <= 2) and (2 < 5) )
#
# ZeroDivisionError: float division by zero

# %%
( (5 <= 2) - (2 < 5) ) ** (5 / 2 - 5 // 2)
# Out:
# (6.123233995736766e-17+1j)
